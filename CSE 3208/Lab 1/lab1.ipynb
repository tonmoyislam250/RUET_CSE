# %%
print("Artificial Intelligence")
# Out:
# Artificial Intelligence

# %%
print(5)
print(3.14)
print(True)
# Out:
# 5
# 3.14
# True

# %%
var = 'Artificial'
var2 ='''Intelligence, supervised learning, unsupervised learning, reinforcement learning'''
var3 = 1557

# %%
trans = str.maketrans('i', '1')

print(var.capitalize())
print(var.casefold())
print(var.center(20))
print(var.count('i'))
print(var.encode())
print(var.endswith('l'))
print(var.expandtabs(4))
print(var.find('i'))
print("This is an {} example.".format(var))
print("{var}".format_map(vars()))
print(var.index('i'))
print(var.isalnum())
print(var.isalpha())
print(var.isascii())
print(var.isdecimal())
print(var.isdigit())
print(var.isidentifier())
print(var.islower())
print(var.isnumeric())
print(var.isprintable())
print(var.isspace())
print(var.istitle())
print(var.isupper())
print('-'.join(var))
print(var.ljust(20))
print(var.lower())
print(var.lstrip('A'))
print(var.translate(trans))
print(var.partition('i'))
print(var.replace('i', '1'))
print(var.rfind('i'))
print(var.rindex('i'))
print(var.rjust(20))
print(var.rpartition('i'))
print(var.rsplit('i'))
print(var.rstrip('l'))
print(var.split('i'))
print(var.splitlines())
print(var.startswith('A'))
print(var.strip('A'))
print(var.swapcase())
print(var.title())
print(var.upper())
print(var.zfill(20))
# Out:
# Artificial
# artificial
#      Artificial
# 3
# b'Artificial'
# True
# Artificial
# 3
# This is an Artificial example.
# Artificial
# 3
# True
# True
# True
# False
# False
# True
# False
# False
# True
# False
# True
# False
# A-r-t-i-f-i-c-i-a-l
# Artificial
# artificial
# rtificial
# Art1f1c1al
# ('Art', 'i', 'ficial')
# Art1f1c1al
# 7
# 7
#           Artificial
# ('Artific', 'i', 'al')
# ['Art', 'f', 'c', 'al']
# Artificia
# ['Art', 'f', 'c', 'al']
# ['Artificial']
# True
# rtificial
# aRTIFICIAL
# Artificial
# ARTIFICIAL
# 0000000000Artificial

# %%
lists = ['Artificial', 'Intelligence', 'supervised', 'learning', 'unsupervised', 'learning', 'reinforcement', 'learning']
print(lists)
for x in lists:
    print(x)
# Out:
# ['Artificial', 'Intelligence', 'supervised', 'learning', 'unsupervised', 'learning', 'reinforcement', 'learning']
# Artificial
# Intelligence
# supervised
# learning
# unsupervised
# learning
# reinforcement
# learning

# %% [markdown]
# ```PYTHON INPUT
